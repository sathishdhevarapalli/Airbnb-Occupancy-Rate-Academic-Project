# %%
import numpy as np
import pandas as pd

# %%
amenities_data=pd.read_csv("C:\\Users\\Sathish Reddy\\Desktop\\R-project\\working_dr\\Final_Amenities_dataset.csv")
data_set=pd.read_csv("C:\\Users\\Sathish Reddy\\Desktop\\R-project\\working_dr\\Listings+Reviews_PM_3-2019to2-20.csv")

# %%
amenities_data.columns
# Out:
# Index(['id', 'new_amenities'], dtype='object')

# %%
data_set.columns
# Out:
# Index(['listing_id', 'reviews_per_month_x', 'listing_url', 'scrape_id',
#        'last_scraped', 'name', 'summary', 'space', 'description',
#        'experiences_offered',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month_y'],
#       dtype='object', length=107)

# %%
new_data = pd.merge(amenities_data, data_set,left_on='id', right_on='listing_id')

# %%
new_data.head()
# Out:
#      id                                      new_amenities  listing_id  \
# 0  2265  ['TV', 'Wifi', 'Air conditioning', 'Free parki...        2265
# 1  5456      ['TV', 'Wifi', 'Air conditioning', 'Heating']        5456
# 2  5769  ['TV', 'Wifi', 'Air conditioning', 'Free parki...        5769
# 3  6413      ['TV', 'Wifi', 'Air conditioning', 'Heating']        6413
# 4  6448  ['TV', 'Wifi', 'Air conditioning', 'Free parki...        6448
#
#    reviews_per_month_x                        listing_url     scrape_id  \
# 0             1.000000  https://www.airbnb.com/rooms/2265  2.020030e+13
# 1             4.500000  https://www.airbnb.com/rooms/5456  2.020030e+13
# 2             2.428571  https://www.airbnb.com/rooms/5769  2.020030e+13
# 3             2.300000  https://www.airbnb.com/rooms/6413  2.020030e+13
# 4             2.888889  https://www.airbnb.com/rooms/6448  2.020030e+13
#
#   last_scraped                                              name  \
# ...

# %%
new_data.drop('id',axis=1,inplace=True)

# %%
new_data.reset_index(drop=True, inplace=True)

# %%
new_data
# Out:
#                                           new_amenities  listing_id  \
# 0     ['TV', 'Wifi', 'Air conditioning', 'Free parki...        2265
# 1         ['TV', 'Wifi', 'Air conditioning', 'Heating']        5456
# 2     ['TV', 'Wifi', 'Air conditioning', 'Free parki...        5769
# 3         ['TV', 'Wifi', 'Air conditioning', 'Heating']        6413
# 4     ['TV', 'Wifi', 'Air conditioning', 'Free parki...        6448
# ...                                                 ...         ...
# 7160      ['TV', 'Wifi', 'Air conditioning', 'Heating']    42518813
# 7161      ['TV', 'Wifi', 'Air conditioning', 'Heating']    42538483
# 7162  ['TV', 'Wifi', 'Air conditioning', 'Free parki...    42541133
# 7163  ['TV', 'Wifi', 'Air conditioning', 'Free parki...    42586551
# 7164  ['TV', 'Wifi', 'Air conditioning', 'Free parki...    42587555
#
#       reviews_per_month_x                            listing_url  \
# 0                1.000000      https://www.airbnb.com/rooms/2265
# ...

# %%
new_data.shape
# Out:
# (7165, 108)

# %%
new_data.to_csv(r'C:\\Users\\Sathish Reddy\\Desktop\\R-project\\Listings+Amenities+ReviewsPm_Final.csv')
