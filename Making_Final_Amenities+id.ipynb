# %%
import numpy as np
import pandas as pd
import re as regex

# %%
data=pd.read_csv("C:\\Users\\Sathish Reddy\\Desktop\\R-project\\working_dr\\Only_Amenities.csv")

# %%
data.head()
# Out:
#      id                                          amenities
# 0  2265  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1  5245  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2  5456  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 3  5769  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 4  6413  {TV,"Cable TV",Internet,Wifi,"Air conditioning...

# %%
len(data['amenities'][0])
# Out:
# 547

# %%
# listings.amenities = listings.amenities.str.replace("[{}]", "").str.replace('"', "")

# %%
data.amenities = data.amenities.str.replace("[{}]", "").str.replace('"', "")

# %%
data['amenities'].head()
# Out:
# 0    TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 1    TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 2    TV,Wifi,Air conditioning,Kitchen,Pets live on ...
# 3    TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 4    TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# Name: amenities, dtype: object

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()

# %%
pd.Series(np.concatenate(data['amenities'].map(lambda amns: amns.split(","))))\
    .value_counts().head(20)\
    .plot(kind='bar')
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)
plt.show();

# %%
y=pd.Series(np.concatenate(data['amenities'].map(lambda amns: amns.split(","))))\
    .value_counts().head(10)

# %%
y
# Out:
# Air conditioning            11469
# Wifi                        11313
# Heating                     11218
# Essentials                  10949
# Kitchen                     10822
# Smoke detector              10770
# TV                           9954
# Free parking on premises     9600
# Shampoo                      9528
# Washer                       9424
# dtype: int64

# %%
data.head()
# Out:
#      id                                          amenities
# 0  2265  TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 1  5245  TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 2  5456  TV,Wifi,Air conditioning,Kitchen,Pets live on ...
# 3  5769  TV,Cable TV,Internet,Wifi,Air conditioning,Kit...
# 4  6413  TV,Cable TV,Internet,Wifi,Air conditioning,Kit...

# %%
new_data=pd.Series(np.concatenate(data['amenities'].map(lambda amns: amns.split(","))))

# %%
type(data['amenities'][0])
# Out:
# str

# %%
for i in range(data.shape[0]):
    data['amenities'][i]=data['amenities'][i].split(',')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['amenities'][0]
# Out:
# ['TV',
#  'Cable TV',
#  'Internet',
#  'Wifi',
#  'Air conditioning',
#  'Kitchen',
#  'Free parking on premises',
#  'Paid parking off premises',
#  'Breakfast',
#  'Pets live on this property',
#  'Dog(s)',
#  'Free street parking',
#  'Heating',
#  'Family/kid friendly',
#  'Washer',
#  'Dryer',
#  'Smoke detector',
#  'Carbon monoxide detector',
#  'Essentials',
#  'Shampoo',
#  'Hangers',
#  'Hair dryer',
#  'Iron',
#  'Laptop friendly workspace',
#  'Self check-in',
#  'Lockbox',
#  'Private entrance',
#  'Hot water',
#  'Bed linens',
#  'Extra pillows and blankets',
#  'Microwave',
#  'Coffee maker',
#  'Refrigerator',
#  'Dishes and silverware',
#  'Cooking basics',
#  'Oven',
#  'Stove',
#  'Garden or backyard']

# %%
type(data['amenities'][0])
# Out:
# list

# %%
data['sat']=data['amenities']

# %%
data.head(2)
# Out:
#      id                                          amenities  \
# 0  2265  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1  5245  [TV, Cable TV, Internet, Wifi, Air conditionin...
#
#                                                  sat
# 0  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1  [TV, Cable TV, Internet, Wifi, Air conditionin...

# %%
z=['Air conditioning','Wifi','Heating','TV', 'Free parking on premises']

# %%
data['sat'][0]
# Out:
# ['TV',
#  'Cable TV',
#  'Internet',
#  'Wifi',
#  'Air conditioning',
#  'Kitchen',
#  'Free parking on premises',
#  'Paid parking off premises',
#  'Breakfast',
#  'Pets live on this property',
#  'Dog(s)',
#  'Free street parking',
#  'Heating',
#  'Family/kid friendly',
#  'Washer',
#  'Dryer',
#  'Smoke detector',
#  'Carbon monoxide detector',
#  'Essentials',
#  'Shampoo',
#  'Hangers',
#  'Hair dryer',
#  'Iron',
#  'Laptop friendly workspace',
#  'Self check-in',
#  'Lockbox',
#  'Private entrance',
#  'Hot water',
#  'Bed linens',
#  'Extra pillows and blankets',
#  'Microwave',
#  'Coffee maker',
#  'Refrigerator',
#  'Dishes and silverware',
#  'Cooking basics',
#  'Oven',
#  'Stove',
#  'Garden or backyard']

# %%
for i in range(data.shape[0]):
    new=[]
    for j in data['sat'][i]:
        if j in z:
            new.append(j)
    data['sat'][i]=new
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['sat'][0]
# Out:
# ['TV', 'Wifi', 'Air conditioning', 'Free parking on premises', 'Heating']

# %%
data['sat'][2]
# Out:
# ['TV', 'Wifi', 'Air conditioning', 'Heating']

# %%
data.head(3)
# Out:
#      id                                          amenities  \
# 0  2265  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1  5245  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 2  5456  [TV, Wifi, Air conditioning, Kitchen, Pets liv...
#
#                                                  sat
# 0  [TV, Wifi, Air conditioning, Free parking on p...
# 1  [TV, Wifi, Air conditioning, Free parking on p...
# 2              [TV, Wifi, Air conditioning, Heating]

# %%
data['new_amenities']=data['sat']

# %%
data.head(3)
# Out:
#      id                                          amenities  \
# 0  2265  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1  5245  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 2  5456  [TV, Wifi, Air conditioning, Kitchen, Pets liv...
#
#                                                  sat  \
# 0  [TV, Wifi, Air conditioning, Free parking on p...
# 1  [TV, Wifi, Air conditioning, Free parking on p...
# 2              [TV, Wifi, Air conditioning, Heating]
#
#                                        new_amenities
# 0  [TV, Wifi, Air conditioning, Free parking on p...
# 1  [TV, Wifi, Air conditioning, Free parking on p...
# 2              [TV, Wifi, Air conditioning, Heating]

# %%
data.drop(['amenities','sat'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#      id                                      new_amenities
# 0  2265  [TV, Wifi, Air conditioning, Free parking on p...
# 1  5245  [TV, Wifi, Air conditioning, Free parking on p...
# 2  5456              [TV, Wifi, Air conditioning, Heating]
# 3  5769  [TV, Wifi, Air conditioning, Free parking on p...
# 4  6413              [TV, Wifi, Air conditioning, Heating]

# %%
data.to_csv(r'C:\\Users\\Sathish Reddy\\Desktop\\R-project\\Final_Amenities_dataset.csv')
